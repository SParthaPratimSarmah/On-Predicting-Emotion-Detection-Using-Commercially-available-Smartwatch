# %%
import pandas as pd
# replace with the actual path to your CSV file
file_path = 'data/Integrated_with_Sema.pkl'
df = pd.read_pickle(file_path)
specific_user_ids = ['621e36f967b776a240e5e7c9', '621e362467b776a2404ad513']
filtered_df = df[df['id'].isin(specific_user_ids)]
filtered_df.to_csv('data/filtered_users.csv', index=False)
filtered_df
# Out:
#                             id       date  nightly_temperature  nremhr  rmssd  \
# 6370  621e362467b776a2404ad513 2021-04-08                  NaN     NaN    NaN
# 6371  621e362467b776a2404ad513 2021-04-09                  NaN     NaN    NaN
# 6372  621e362467b776a2404ad513 2021-04-10                  NaN     NaN    NaN
# 6373  621e362467b776a2404ad513 2021-04-12                  NaN     NaN    NaN
# 6374  621e362467b776a2404ad513 2021-04-13                  NaN     NaN    NaN
# ...                        ...        ...                  ...     ...    ...
# 7236  621e36f967b776a240e5e7c9 2021-08-03                  NaN     NaN    NaN
# 7237  621e36f967b776a240e5e7c9 2021-08-04                  NaN     NaN    NaN
# 7238  621e36f967b776a240e5e7c9 2021-08-05                  NaN     NaN    NaN
# 7239  621e36f967b776a240e5e7c9 2021-08-06                  NaN     NaN    NaN
# 7240  621e36f967b776a240e5e7c9 2021-08-07                  NaN     NaN    NaN
#
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216 entries, 6370 to 7240
# Data columns (total 78 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                216 non-null    object
#  1   date                              216 non-null    datetime64[ns]
#  2   nightly_temperature               92 non-null     float64
#  3   nremhr                            92 non-null     float64
#  4   rmssd                             92 non-null     float64
#  5   entropy                           92 non-null     float64
#  6   spo2                              80 non-null     float64
#  7   full_sleep_breathing_rate         93 non-null     float64
#  8   full_sleep_standard_deviation     93 non-null     float64
#  9   full_sleep_signal_to_noise        93 non-null     float64
#  10  deep_sleep_breathing_rate         93 non-null     float64
# ...

# %%
columns_to_check = ['ALERT', 'HAPPY', 'NEUTRAL',
                    'RESTED/RELAXED', 'SAD', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME', 'HOME_OFFICE', 'OTHER', 'OUTDOORS',
                    'TRANSIT', 'WORK/SCHOOL']
filtered_df = filtered_df[filtered_df[columns_to_check].any(axis=1)].copy()

# %%
filtered_df
# Out:
#                             id       date  nightly_temperature  nremhr  \
# 6380  621e362467b776a2404ad513 2021-04-22                  NaN     NaN
# 6381  621e362467b776a2404ad513 2021-04-23                  NaN     NaN
# 6382  621e362467b776a2404ad513 2021-04-24                  NaN     NaN
# 6383  621e362467b776a2404ad513 2021-04-25                  NaN     NaN
# 6384  621e362467b776a2404ad513 2021-04-26                  NaN     NaN
# ...                        ...        ...                  ...     ...
# 7224  621e36f967b776a240e5e7c9 2021-07-22            34.717732  60.743
# 7225  621e36f967b776a240e5e7c9 2021-07-23            34.179930  63.271
# 7226  621e36f967b776a240e5e7c9 2021-07-24                  NaN     NaN
# 7227  621e36f967b776a240e5e7c9 2021-07-25            34.404958  60.449
# 7228  621e36f967b776a240e5e7c9 2021-07-26            34.354848     NaN
#
#        rmssd  entropy  spo2  full_sleep_breathing_rate  \
# 6380     NaN      NaN   NaN                        NaN
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 78 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                165 non-null    object
#  1   date                              165 non-null    datetime64[ns]
#  2   nightly_temperature               87 non-null     float64
#  3   nremhr                            87 non-null     float64
#  4   rmssd                             87 non-null     float64
#  5   entropy                           87 non-null     float64
#  6   spo2                              72 non-null     float64
#  7   full_sleep_breathing_rate         88 non-null     float64
#  8   full_sleep_standard_deviation     88 non-null     float64
#  9   full_sleep_signal_to_noise        88 non-null     float64
#  10  deep_sleep_breathing_rate         88 non-null     float64
# ...

# %%
filtered_df.columns
# Out:
# Index(['id', 'date', 'nightly_temperature', 'nremhr', 'rmssd', 'entropy',
#        'spo2', 'full_sleep_breathing_rate', 'full_sleep_standard_deviation',
#        'full_sleep_signal_to_noise', 'deep_sleep_breathing_rate',
#        'deep_sleep_standard_deviation', 'deep_sleep_signal_to_noise',
#        'light_sleep_breathing_rate', 'light_sleep_standard_deviation',
#        'light_sleep_signal_to_noise', 'rem_sleep_breathing_rate',
#        'rem_sleep_standard_deviation', 'rem_sleep_signal_to_noise',
#        'stress_score', 'sleep_points_percentage', 'exertion_points_percentage',
#        'responsiveness_points_percentage', 'daily_temperature_variation',
#        'badgeType', 'calories', 'filteredDemographicVO2Max', 'distance',
#        'activityType', 'bpm', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'mindfulness_session', 'scl_avg', 'resting_hr', 'sleep_duration',
# ...

# %%
filtered_df = filtered_df.drop(
    ['light_sleep_breathing_rate', 'light_sleep_standard_deviation', 'light_sleep_signal_to_noise', 'scl_avg'], axis=1)
filtered_df
# Out:
#                             id       date  nightly_temperature  nremhr  \
# 6380  621e362467b776a2404ad513 2021-04-22                  NaN     NaN
# 6381  621e362467b776a2404ad513 2021-04-23                  NaN     NaN
# 6382  621e362467b776a2404ad513 2021-04-24                  NaN     NaN
# 6383  621e362467b776a2404ad513 2021-04-25                  NaN     NaN
# 6384  621e362467b776a2404ad513 2021-04-26                  NaN     NaN
# ...                        ...        ...                  ...     ...
# 7224  621e36f967b776a240e5e7c9 2021-07-22            34.717732  60.743
# 7225  621e36f967b776a240e5e7c9 2021-07-23            34.179930  63.271
# 7226  621e36f967b776a240e5e7c9 2021-07-24                  NaN     NaN
# 7227  621e36f967b776a240e5e7c9 2021-07-25            34.404958  60.449
# 7228  621e36f967b776a240e5e7c9 2021-07-26            34.354848     NaN
#
#        rmssd  entropy  spo2  full_sleep_breathing_rate  \
# 6380     NaN      NaN   NaN                        NaN
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 74 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                165 non-null    object
#  1   date                              165 non-null    datetime64[ns]
#  2   nightly_temperature               87 non-null     float64
#  3   nremhr                            87 non-null     float64
#  4   rmssd                             87 non-null     float64
#  5   entropy                           87 non-null     float64
#  6   spo2                              72 non-null     float64
#  7   full_sleep_breathing_rate         88 non-null     float64
#  8   full_sleep_standard_deviation     88 non-null     float64
#  9   full_sleep_signal_to_noise        88 non-null     float64
#  10  deep_sleep_breathing_rate         88 non-null     float64
# ...

# %%
filtered_df = filtered_df.drop(
    ['<no-response>'], axis=1)
filtered_df
# Out:
#                             id       date  nightly_temperature  nremhr  \
# 6380  621e362467b776a2404ad513 2021-04-22                  NaN     NaN
# 6381  621e362467b776a2404ad513 2021-04-23                  NaN     NaN
# 6382  621e362467b776a2404ad513 2021-04-24                  NaN     NaN
# 6383  621e362467b776a2404ad513 2021-04-25                  NaN     NaN
# 6384  621e362467b776a2404ad513 2021-04-26                  NaN     NaN
# ...                        ...        ...                  ...     ...
# 7224  621e36f967b776a240e5e7c9 2021-07-22            34.717732  60.743
# 7225  621e36f967b776a240e5e7c9 2021-07-23            34.179930  63.271
# 7226  621e36f967b776a240e5e7c9 2021-07-24                  NaN     NaN
# 7227  621e36f967b776a240e5e7c9 2021-07-25            34.404958  60.449
# 7228  621e36f967b776a240e5e7c9 2021-07-26            34.354848     NaN
#
#        rmssd  entropy  spo2  full_sleep_breathing_rate  \
# 6380     NaN      NaN   NaN                        NaN
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 73 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                165 non-null    object
#  1   date                              165 non-null    datetime64[ns]
#  2   nightly_temperature               87 non-null     float64
#  3   nremhr                            87 non-null     float64
#  4   rmssd                             87 non-null     float64
#  5   entropy                           87 non-null     float64
#  6   spo2                              72 non-null     float64
#  7   full_sleep_breathing_rate         88 non-null     float64
#  8   full_sleep_standard_deviation     88 non-null     float64
#  9   full_sleep_signal_to_noise        88 non-null     float64
#  10  deep_sleep_breathing_rate         88 non-null     float64
# ...

# %%
filtered_df.columns
# Out:
# Index(['id', 'date', 'nightly_temperature', 'nremhr', 'rmssd', 'entropy',
#        'spo2', 'full_sleep_breathing_rate', 'full_sleep_standard_deviation',
#        'full_sleep_signal_to_noise', 'deep_sleep_breathing_rate',
#        'deep_sleep_standard_deviation', 'deep_sleep_signal_to_noise',
#        'rem_sleep_breathing_rate', 'rem_sleep_standard_deviation',
#        'rem_sleep_signal_to_noise', 'stress_score', 'sleep_points_percentage',
#        'exertion_points_percentage', 'responsiveness_points_percentage',
#        'daily_temperature_variation', 'badgeType', 'calories',
#        'filteredDemographicVO2Max', 'distance', 'activityType', 'bpm',
#        'lightly_active_minutes', 'moderately_active_minutes',
#        'very_active_minutes', 'sedentary_minutes', 'mindfulness_session',
#        'resting_hr', 'sleep_duration', 'minutesToFallAsleep', 'minutesAsleep',
#        'minutesAwake', 'minutesAfterWakeup', 'sleep_efficiency',
# ...

# %%
check = filtered_df[['id', 'date', 'bpm', 'calories', 'distance', 'filteredDemographicVO2Max', 'lightly_active_minutes', 'moderately_active_minutes',
                     'very_active_minutes', 'sedentary_minutes', 'mindfulness_session',
                     'resting_hr', 'steps', 'minutes_in_default_zone_1',
                     'minutes_below_default_zone_1', 'minutes_in_default_zone_2',
                     'minutes_in_default_zone_3', 'age', 'gender', 'bmi', 'step_goal',
                     'min_goal', 'max_goal', 'step_goal_label', 'ALERT', 'ANGER', 'FEAR',
                     'HAPPY', 'NEUTRAL', 'RESTED/RELAXED', 'SAD', 'SURPRISE',
                     'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME', 'HOME_OFFICE',
                     'OTHER', 'OUTDOORS', 'TRANSIT', 'WORK/SCHOOL']].copy()
check
# Out:
#                             id       date        bpm  calories  distance  \
# 6380  621e362467b776a2404ad513 2021-04-22        NaN       NaN       NaN
# 6381  621e362467b776a2404ad513 2021-04-23        NaN       NaN       NaN
# 6382  621e362467b776a2404ad513 2021-04-24        NaN       NaN       NaN
# 6383  621e362467b776a2404ad513 2021-04-25        NaN       NaN       NaN
# 6384  621e362467b776a2404ad513 2021-04-26        NaN       NaN       NaN
# ...                        ...        ...        ...       ...       ...
# 7224  621e36f967b776a240e5e7c9 2021-07-22  76.741228   2098.93    2966.5
# 7225  621e36f967b776a240e5e7c9 2021-07-23  79.638345   2385.90    6573.6
# 7226  621e36f967b776a240e5e7c9 2021-07-24  95.209614   1884.40    2682.2
# 7227  621e36f967b776a240e5e7c9 2021-07-25  75.835454   2181.26    5228.7
# 7228  621e36f967b776a240e5e7c9 2021-07-26        NaN   1051.46    2463.5
#
#       filteredDemographicVO2Max lightly_active_minutes  \
# ...

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            165 non-null    object
#  1   date                          165 non-null    datetime64[ns]
#  2   bpm                           119 non-null    float64
#  3   calories                      121 non-null    float64
#  4   distance                      120 non-null    float64
#  5   filteredDemographicVO2Max     120 non-null    float64
#  6   lightly_active_minutes        121 non-null    object
#  7   moderately_active_minutes     121 non-null    object
#  8   very_active_minutes           121 non-null    object
#  9   sedentary_minutes             121 non-null    object
#  10  mindfulness_session           121 non-null    object
#  11  resting_hr                    117 non-null    float64
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['bpm']] = imputer.fit_transform(check[['bpm']])

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            165 non-null    object
#  1   date                          165 non-null    datetime64[ns]
#  2   bpm                           165 non-null    float64
#  3   calories                      121 non-null    float64
#  4   distance                      120 non-null    float64
#  5   filteredDemographicVO2Max     120 non-null    float64
#  6   lightly_active_minutes        121 non-null    object
#  7   moderately_active_minutes     121 non-null    object
#  8   very_active_minutes           121 non-null    object
#  9   sedentary_minutes             121 non-null    object
#  10  mindfulness_session           121 non-null    object
#  11  resting_hr                    117 non-null    float64
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['calories',
       'distance']] = imputer.fit_transform(check[['calories', 'distance']])

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            165 non-null    object
#  1   date                          165 non-null    datetime64[ns]
#  2   bpm                           165 non-null    float64
#  3   calories                      165 non-null    float64
#  4   distance                      165 non-null    float64
#  5   filteredDemographicVO2Max     120 non-null    float64
#  6   lightly_active_minutes        121 non-null    object
#  7   moderately_active_minutes     121 non-null    object
#  8   very_active_minutes           121 non-null    object
#  9   sedentary_minutes             121 non-null    object
#  10  mindfulness_session           121 non-null    object
#  11  resting_hr                    117 non-null    float64
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['very_active_minutes', 'sedentary_minutes']] = imputer.fit_transform(
    check[['very_active_minutes', 'sedentary_minutes']])

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            165 non-null    object
#  1   date                          165 non-null    datetime64[ns]
#  2   bpm                           165 non-null    float64
#  3   calories                      165 non-null    float64
#  4   distance                      165 non-null    float64
#  5   filteredDemographicVO2Max     120 non-null    float64
#  6   lightly_active_minutes        121 non-null    object
#  7   moderately_active_minutes     121 non-null    object
#  8   very_active_minutes           165 non-null    float64
#  9   sedentary_minutes             165 non-null    float64
#  10  mindfulness_session           121 non-null    object
#  11  resting_hr                    117 non-null    float64
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['filteredDemographicVO2Max']] = imputer.fit_transform(
    check[['filteredDemographicVO2Max']])

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            165 non-null    object
#  1   date                          165 non-null    datetime64[ns]
#  2   bpm                           165 non-null    float64
#  3   calories                      165 non-null    float64
#  4   distance                      165 non-null    float64
#  5   filteredDemographicVO2Max     165 non-null    float64
#  6   lightly_active_minutes        121 non-null    object
#  7   moderately_active_minutes     121 non-null    object
#  8   very_active_minutes           165 non-null    float64
#  9   sedentary_minutes             165 non-null    float64
#  10  mindfulness_session           121 non-null    object
#  11  resting_hr                    117 non-null    float64
# ...

# %%
check.columns
# Out:
# Index(['id', 'date', 'bpm', 'calories', 'distance',
#        'filteredDemographicVO2Max', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'mindfulness_session', 'resting_hr', 'steps',
#        'minutes_in_default_zone_1', 'minutes_below_default_zone_1',
#        'minutes_in_default_zone_2', 'minutes_in_default_zone_3', 'age',
#        'gender', 'bmi', 'step_goal', 'min_goal', 'max_goal', 'step_goal_label',
#        'ALERT', 'ANGER', 'FEAR', 'HAPPY', 'NEUTRAL', 'RESTED/RELAXED', 'SAD',
#        'SURPRISE', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME',
#        'HOME_OFFICE', 'OTHER', 'OUTDOORS', 'TRANSIT', 'WORK/SCHOOL'],
#       dtype='object')

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['lightly_active_minutes',
       'moderately_active_minutes', 'resting_hr', 'steps',
       'minutes_in_default_zone_1', 'minutes_below_default_zone_1',
       'minutes_in_default_zone_2', 'minutes_in_default_zone_3']] = imputer.fit_transform(
    check[['lightly_active_minutes',
           'moderately_active_minutes', 'resting_hr', 'steps',
           'minutes_in_default_zone_1', 'minutes_below_default_zone_1',
           'minutes_in_default_zone_2', 'minutes_in_default_zone_3']])

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            165 non-null    object
#  1   date                          165 non-null    datetime64[ns]
#  2   bpm                           165 non-null    float64
#  3   calories                      165 non-null    float64
#  4   distance                      165 non-null    float64
#  5   filteredDemographicVO2Max     165 non-null    float64
#  6   lightly_active_minutes        165 non-null    float64
#  7   moderately_active_minutes     165 non-null    float64
#  8   very_active_minutes           165 non-null    float64
#  9   sedentary_minutes             165 non-null    float64
#  10  mindfulness_session           121 non-null    object
#  11  resting_hr                    165 non-null    float64
# ...

# %%
check.columns
# Out:
# Index(['id', 'date', 'bpm', 'calories', 'distance',
#        'filteredDemographicVO2Max', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'mindfulness_session', 'resting_hr', 'steps',
#        'minutes_in_default_zone_1', 'minutes_below_default_zone_1',
#        'minutes_in_default_zone_2', 'minutes_in_default_zone_3', 'age',
#        'gender', 'bmi', 'step_goal', 'min_goal', 'max_goal', 'step_goal_label',
#        'ALERT', 'ANGER', 'FEAR', 'HAPPY', 'NEUTRAL', 'RESTED/RELAXED', 'SAD',
#        'SURPRISE', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME',
#        'HOME_OFFICE', 'OTHER', 'OUTDOORS', 'TRANSIT', 'WORK/SCHOOL'],
#       dtype='object')

# %%
check1 = check[['id', 'date', 'bpm', 'calories', 'distance',
                'filteredDemographicVO2Max', 'lightly_active_minutes',
               'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps', 'ALERT', 'ANGER', 'FEAR', 'HAPPY', 'NEUTRAL', 'RESTED/RELAXED', 'SAD',
                'SURPRISE', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME',
                'HOME_OFFICE', 'OTHER', 'OUTDOORS', 'TRANSIT', 'WORK/SCHOOL']].copy()

# %%
check1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 6380 to 7228
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         165 non-null    object
#  1   date                       165 non-null    datetime64[ns]
#  2   bpm                        165 non-null    float64
#  3   calories                   165 non-null    float64
#  4   distance                   165 non-null    float64
#  5   filteredDemographicVO2Max  165 non-null    float64
#  6   lightly_active_minutes     165 non-null    float64
#  7   moderately_active_minutes  165 non-null    float64
#  8   very_active_minutes        165 non-null    float64
#  9   sedentary_minutes          165 non-null    float64
#  10  resting_hr                 165 non-null    float64
#  11  steps                      165 non-null    float64
#  12  ALERT                      165 non-null    object
# ...

# %%
columns_to_encode = ['ALERT', 'ANGER', 'FEAR', 'HAPPY', 'NEUTRAL',
                     'RESTED/RELAXED', 'SAD', 'SURPRISE', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME', 'HOME_OFFICE', 'OTHER', 'OUTDOORS',
                     'TRANSIT', 'WORK/SCHOOL']

# Ensure these columns exist in the DataFrame
columns_to_encode = [
    col for col in columns_to_encode if col in check1.columns]

# Apply one-hot encoding to the specified columns
X_input_encoded = pd.get_dummies(check1, columns=columns_to_encode)

# Print the original and encoded dataframes
print("Original DataFrame:")
print(check1.head())

print("\nDataFrame after One-Hot Encoding:")
print(X_input_encoded.head())
# Out:
# Original DataFrame:
#                             id       date        bpm     calories  \
# 6380  621e362467b776a2404ad513 2021-04-22  83.065885  2401.796777
# 6381  621e362467b776a2404ad513 2021-04-23  83.065885  2401.796777
# 6382  621e362467b776a2404ad513 2021-04-24  83.065885  2401.796777
# 6383  621e362467b776a2404ad513 2021-04-25  83.065885  2401.796777
# 6384  621e362467b776a2404ad513 2021-04-26  83.065885  2401.796777
#
#          distance  filteredDemographicVO2Max  lightly_active_minutes  \
# 6380  6621.301667                  41.420063              206.966942
# 6381  6621.301667                  41.420063              206.966942
# 6382  6621.301667                  41.420063              206.966942
# 6383  6621.301667                  41.420063              206.966942
# 6384  6621.301667                  41.420063              206.966942
#
#       moderately_active_minutes  very_active_minutes  sedentary_minutes  ...  \
# ...

# %%
check1
# Out:
#                             id       date        bpm     calories  \
# 6380  621e362467b776a2404ad513 2021-04-22  83.065885  2401.796777
# 6381  621e362467b776a2404ad513 2021-04-23  83.065885  2401.796777
# 6382  621e362467b776a2404ad513 2021-04-24  83.065885  2401.796777
# 6383  621e362467b776a2404ad513 2021-04-25  83.065885  2401.796777
# 6384  621e362467b776a2404ad513 2021-04-26  83.065885  2401.796777
# ...                        ...        ...        ...          ...
# 7224  621e36f967b776a240e5e7c9 2021-07-22  76.741228  2098.930000
# 7225  621e36f967b776a240e5e7c9 2021-07-23  79.638345  2385.900000
# 7226  621e36f967b776a240e5e7c9 2021-07-24  95.209614  1884.400000
# 7227  621e36f967b776a240e5e7c9 2021-07-25  75.835454  2181.260000
# 7228  621e36f967b776a240e5e7c9 2021-07-26  83.065885  1051.460000
#
#          distance  filteredDemographicVO2Max  lightly_active_minutes  \
# 6380  6621.301667                  41.420063              206.966942
# ...

# %%
X_input_encoded.head()
# Out:
#                             id       date        bpm     calories  \
# 6380  621e362467b776a2404ad513 2021-04-22  83.065885  2401.796777
# 6381  621e362467b776a2404ad513 2021-04-23  83.065885  2401.796777
# 6382  621e362467b776a2404ad513 2021-04-24  83.065885  2401.796777
# 6383  621e362467b776a2404ad513 2021-04-25  83.065885  2401.796777
# 6384  621e362467b776a2404ad513 2021-04-26  83.065885  2401.796777
#
#          distance  filteredDemographicVO2Max  lightly_active_minutes  \
# 6380  6621.301667                  41.420063              206.966942
# 6381  6621.301667                  41.420063              206.966942
# 6382  6621.301667                  41.420063              206.966942
# 6383  6621.301667                  41.420063              206.966942
# 6384  6621.301667                  41.420063              206.966942
#
#       moderately_active_minutes  very_active_minutes  sedentary_minutes  ...  \
# ...

# %%
X_input_encoded.describe()
# Out:
#                                 date         bpm     calories      distance  \
# count                            165  165.000000   165.000000    165.000000
# mean   2021-06-11 07:25:05.454545408   83.065885  2401.796777   6586.774869
# min              2021-04-22 00:00:00   69.661471  1051.460000      4.300000
# 25%              2021-05-22 00:00:00   79.941841  2305.620000   4937.300000
# 50%              2021-06-12 00:00:00   83.065885  2401.796777   6621.301667
# 75%              2021-07-03 00:00:00   84.744667  2464.150000   7669.400000
# max              2021-07-26 00:00:00  103.691655  3727.370000  22305.700000
# std                              NaN    5.666292   308.411702   3222.942225
#
#        filteredDemographicVO2Max  lightly_active_minutes  \
# count                 165.000000              165.000000
# mean                   41.420063              206.966942
# min                    36.961850                0.000000
# ...

# %%
import plotly.express as px
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
numeric_cols = X_input_encoded.select_dtypes(
    include=np.number).columns.tolist()


numeric_cols
# Out:
# ['bpm',
#  'calories',
#  'distance',
#  'filteredDemographicVO2Max',
#  'lightly_active_minutes',
#  'moderately_active_minutes',
#  'very_active_minutes',
#  'sedentary_minutes',
#  'resting_hr',
#  'steps']

# %%
categorical_cols = X_input_encoded.select_dtypes('bool').columns.tolist()
categorical_cols
# Out:
# ['ALERT_False',
#  'ALERT_True',
#  'ANGER_False',
#  'ANGER_True',
#  'FEAR_False',
#  'FEAR_True',
#  'HAPPY_False',
#  'HAPPY_True',
#  'NEUTRAL_False',
#  'NEUTRAL_True',
#  'RESTED/RELAXED_False',
#  'RESTED/RELAXED_True',
#  'SAD_False',
#  'SAD_True',
#  'SURPRISE_False',
#  'SURPRISE_True',
#  'TENSE/ANXIOUS_False',
#  'TENSE/ANXIOUS_True',
#  'TIRED_False',
#  'TIRED_True',
#  'ENTERTAINMENT_False',
#  'ENTERTAINMENT_True',
#  'GYM_False',
#  'GYM_True',
#  'HOME_False',
#  'HOME_True',
#  'HOME_OFFICE_False',
#  'OTHER_False',
#  'OTHER_True',
#  'OUTDOORS_False',
#  'OUTDOORS_True',
#  'TRANSIT_False',
#  'TRANSIT_True',
#  'WORK/SCHOOL_False',
#  'WORK/SCHOOL_True']

# %%
X_input_encoded[numeric_cols].describe()
# Out:
#               bpm     calories      distance  filteredDemographicVO2Max  \
# count  165.000000   165.000000    165.000000                 165.000000
# mean    83.065885  2401.796777   6586.774869                  41.420063
# std      5.666292   308.411702   3222.942225                   3.501497
# min     69.661471  1051.460000      4.300000                  36.961850
# 25%     79.941841  2305.620000   4937.300000                  37.840730
# 50%     83.065885  2401.796777   6621.301667                  41.420063
# 75%     84.744667  2464.150000   7669.400000                  45.204050
# max    103.691655  3727.370000  22305.700000                  46.670210
#
#        lightly_active_minutes  moderately_active_minutes  very_active_minutes  \
# count              165.000000                 165.000000           165.000000
# mean               206.966942                  19.157025            21.892562
# std                 72.407800                  15.872975            21.666204
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_input_encoded[numeric_cols])
# Out:
# MinMaxScaler()

# %%
print('Minimum:')
list(scaler.data_min_)
# Out:
# Minimum:
# [69.66147101802241,
#  1051.46,
#  4.3,
#  36.961850000000005,
#  0.0,
#  0.0,
#  0.0,
#  167.0,
#  61.253424644470215,
#  6.0]

# %%
print('Maximum:')
list(scaler.data_max_)
# Out:
# Maximum:
# [103.6916548797737,
#  3727.37,
#  22305.7,
#  46.670210000000004,
#  432.0,
#  92.0,
#  206.0,
#  1440.0,
#  82.80441665649414,
#  32360.0]

# %%
X_input_encoded[numeric_cols] = scaler.transform(X_input_encoded[numeric_cols])

# %%
X_input_encoded.describe()
# Out:
#                                 date         bpm    calories    distance  \
# count                            165  165.000000  165.000000  165.000000
# mean   2021-06-11 07:25:05.454545408    0.393898    0.504627    0.295160
# min              2021-04-22 00:00:00    0.000000    0.000000    0.000000
# 25%              2021-05-22 00:00:00    0.302096    0.468685    0.221197
# 50%              2021-06-12 00:00:00    0.393898    0.504627    0.296708
# 75%              2021-07-03 00:00:00    0.443230    0.527929    0.343705
# max              2021-07-26 00:00:00    1.000000    1.000000    1.000000
# std                              NaN    0.166508    0.115255    0.144517
#
#        filteredDemographicVO2Max  lightly_active_minutes  \
# count                 165.000000              165.000000
# mean                    0.459214                0.479090
# min                     0.000000                0.000000
# 25%                     0.090528                0.393519
# ...

# %%
X_input_encoded
# Out:
#                             id       date       bpm  calories  distance  \
# 6380  621e362467b776a2404ad513 2021-04-22  0.393898  0.504627  0.296708
# 6381  621e362467b776a2404ad513 2021-04-23  0.393898  0.504627  0.296708
# 6382  621e362467b776a2404ad513 2021-04-24  0.393898  0.504627  0.296708
# 6383  621e362467b776a2404ad513 2021-04-25  0.393898  0.504627  0.296708
# 6384  621e362467b776a2404ad513 2021-04-26  0.393898  0.504627  0.296708
# ...                        ...        ...       ...       ...       ...
# 7224  621e36f967b776a240e5e7c9 2021-07-22  0.208043  0.391444  0.132826
# 7225  621e36f967b776a240e5e7c9 2021-07-23  0.293177  0.498686  0.294569
# 7226  621e36f967b776a240e5e7c9 2021-07-24  0.750749  0.311274  0.120078
# 7227  621e36f967b776a240e5e7c9 2021-07-25  0.181427  0.422212  0.234263
# 7228  621e36f967b776a240e5e7c9 2021-07-26  0.393898  0.000000  0.110271
#
#       filteredDemographicVO2Max  lightly_active_minutes  \
# ...

# %%
X_input_encoded.to_csv('ML_algorithm/data/encoded_two_users.csv', index=False)

# %%
X_input_encoded.columns
# Out:
# Index(['id', 'date', 'bpm', 'calories', 'distance',
#        'filteredDemographicVO2Max', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'resting_hr', 'steps', 'ALERT_False', 'ALERT_True', 'ANGER_False',
#        'ANGER_True', 'FEAR_False', 'FEAR_True', 'HAPPY_False', 'HAPPY_True',
#        'NEUTRAL_False', 'NEUTRAL_True', 'RESTED/RELAXED_False',
#        'RESTED/RELAXED_True', 'SAD_False', 'SAD_True', 'SURPRISE_False',
#        'SURPRISE_True', 'TENSE/ANXIOUS_False', 'TENSE/ANXIOUS_True',
#        'TIRED_False', 'TIRED_True', 'ENTERTAINMENT_False',
#        'ENTERTAINMENT_True', 'GYM_False', 'GYM_True', 'HOME_False',
#        'HOME_True', 'HOME_OFFICE_False', 'OTHER_False', 'OTHER_True',
#        'OUTDOORS_False', 'OUTDOORS_True', 'TRANSIT_False', 'TRANSIT_True',
#        'WORK/SCHOOL_False', 'WORK/SCHOOL_True'],
#       dtype='object')

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('ML_algorithm/data/encoded_two_users.csv')

# Combine emotion columns into a single "Emotions" column
emotion_columns = ['ALERT_True', 'ANGER_True', 'FEAR_True', 'HAPPY_True', 'NEUTRAL_True',
                   'RESTED/RELAXED_True', 'SAD_True', 'SURPRISE_True', 'TENSE/ANXIOUS_True', 'TIRED_True']
df['Emotions'] = df[emotion_columns].idxmax(
    axis=1).apply(lambda x: x.replace('_True', ''))

# Drop the original emotion columns
df.drop(emotion_columns, axis=1, inplace=True)

# Optional: Drop the 'False' columns as well if they are no longer needed
false_columns = [col for col in df.columns if col.endswith('_False')]
df.drop(false_columns, axis=1, inplace=True)

# Save the DataFrame with the new "Emotions" column
df.to_csv(
    'ML_algorithm/data/path_to_save_updated_csv_file_two_users.csv', index=False)

# Display the first few rows to verify the changes
df.head()
# Out:
#                          id        date       bpm  calories  distance  \
# 0  621e362467b776a2404ad513  2021-04-22  0.393898  0.504627  0.296708
# 1  621e362467b776a2404ad513  2021-04-23  0.393898  0.504627  0.296708
# 2  621e362467b776a2404ad513  2021-04-24  0.393898  0.504627  0.296708
# 3  621e362467b776a2404ad513  2021-04-25  0.393898  0.504627  0.296708
# 4  621e362467b776a2404ad513  2021-04-26  0.393898  0.504627  0.296708
#
#    filteredDemographicVO2Max  lightly_active_minutes  \
# 0                   0.459214                 0.47909
# 1                   0.459214                 0.47909
# 2                   0.459214                 0.47909
# 3                   0.459214                 0.47909
# 4                   0.459214                 0.47909
#
#    moderately_active_minutes  very_active_minutes  sedentary_minutes  \
# 0                   0.208229             0.106275           0.521512
# 1                   0.208229             0.106275           0.521512
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load the CSV file into a DataFrame
df = pd.read_csv('ML_algorithm/data/encoded_two_users.csv')

# Combine emotion columns into a single "Emotions" column
emotion_columns = ['ALERT_True', 'ANGER_True', 'FEAR_True', 'HAPPY_True', 'NEUTRAL_True',
                   'RESTED/RELAXED_True', 'SAD_True', 'SURPRISE_True', 'TENSE/ANXIOUS_True', 'TIRED_True']
df['Emotions'] = df[emotion_columns].idxmax(
    axis=1).apply(lambda x: x.replace('_True', ''))

# Drop the original emotion columns
df.drop(emotion_columns, axis=1, inplace=True)

# Optional: Drop the 'False' columns as well if they are no longer needed
false_columns = [col for col in df.columns if col.endswith('_False')]
df.drop(false_columns, axis=1, inplace=True)

# Select features and target
features = df.drop(['id', 'date', 'Emotions'], axis=1)
target = df['Emotions']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42)

# Train a model (RandomForestClassifier used as an example)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Add predictions to the DataFrame
df['Predicted_Emotions'] = model.predict(features)

# Save the DataFrame with the new "Emotions" column
df.to_csv('path_to_save_updated_csv_file.csv', index=False)
# Out:
# Accuracy: 0.48484848484848486

# %%
X_input_encoded.columns
# Out:
# Index(['id', 'date', 'bpm', 'calories', 'distance',
#        'filteredDemographicVO2Max', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'resting_hr', 'steps', 'ALERT_False', 'ALERT_True', 'ANGER_False',
#        'ANGER_True', 'FEAR_False', 'FEAR_True', 'HAPPY_False', 'HAPPY_True',
#        'NEUTRAL_False', 'NEUTRAL_True', 'RESTED/RELAXED_False',
#        'RESTED/RELAXED_True', 'SAD_False', 'SAD_True', 'SURPRISE_False',
#        'SURPRISE_True', 'TENSE/ANXIOUS_False', 'TENSE/ANXIOUS_True',
#        'TIRED_False', 'TIRED_True', 'ENTERTAINMENT_False',
#        'ENTERTAINMENT_True', 'GYM_False', 'GYM_True', 'HOME_False',
#        'HOME_True', 'HOME_OFFICE_False', 'OTHER_False', 'OTHER_True',
#        'OUTDOORS_False', 'OUTDOORS_True', 'TRANSIT_False', 'TRANSIT_True',
#        'WORK/SCHOOL_False', 'WORK/SCHOOL_True'],
#       dtype='object')

# %%
df1 = X_input_encoded[['bpm', 'calories', 'distance',
                       'filteredDemographicVO2Max', 'lightly_active_minutes',
                       'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
                       'resting_hr', 'steps', 'ALERT_False', 'ALERT_True', 'ANGER_False',
                       'ANGER_True', 'FEAR_False', 'FEAR_True', 'HAPPY_False', 'HAPPY_True',
                       'NEUTRAL_False', 'NEUTRAL_True', 'RESTED/RELAXED_False',
                       'RESTED/RELAXED_True', 'SAD_False', 'SAD_True', 'SURPRISE_False',
                       'SURPRISE_True', 'TENSE/ANXIOUS_False', 'TENSE/ANXIOUS_True',
                       'TIRED_False', 'TIRED_True', 'ENTERTAINMENT_False',
                       'ENTERTAINMENT_True', 'GYM_False', 'GYM_True', 'HOME_False',
                       'HOME_True', 'HOME_OFFICE_False', 'OTHER_False', 'OTHER_True',
                       'OUTDOORS_False', 'OUTDOORS_True', 'TRANSIT_False', 'TRANSIT_True',
                       'WORK/SCHOOL_False', 'WORK/SCHOOL_True']].copy()
df1
# Out:
#            bpm  calories  distance  filteredDemographicVO2Max  \
# 6380  0.393898  0.504627  0.296708                   0.459214
# 6381  0.393898  0.504627  0.296708                   0.459214
# 6382  0.393898  0.504627  0.296708                   0.459214
# 6383  0.393898  0.504627  0.296708                   0.459214
# 6384  0.393898  0.504627  0.296708                   0.459214
# ...        ...       ...       ...                        ...
# 7224  0.208043  0.391444  0.132826                   0.056263
# 7225  0.293177  0.498686  0.294569                   0.045026
# 7226  0.750749  0.311274  0.120078                   0.033469
# 7227  0.181427  0.422212  0.234263                   0.023668
# 7228  0.393898  0.000000  0.110271                   0.024991
#
#       lightly_active_minutes  moderately_active_minutes  very_active_minutes  \
# 6380                0.479090                   0.208229             0.106275
# ...

# %%
cor = df1.corr()
cor
# Out:
#                                     bpm      calories  distance  \
# bpm                        1.000000e+00  2.681401e-01  0.108806
# calories                   2.681401e-01  1.000000e+00  0.876977
# distance                   1.088059e-01  8.769773e-01  1.000000
# filteredDemographicVO2Max  4.334865e-01 -5.919681e-02 -0.377598
# lightly_active_minutes    -2.404811e-01  6.489837e-01  0.725924
# moderately_active_minutes  7.452886e-02  7.104875e-01  0.836779
# very_active_minutes        2.607041e-01  6.890680e-01  0.780950
# sedentary_minutes          4.815713e-01 -2.769820e-01 -0.323355
# resting_hr                 5.417886e-01 -5.652814e-02 -0.316231
# steps                      9.036395e-02  8.680069e-01  0.998439
# ALERT_False               -2.741142e-01  8.867233e-02  0.271504
# ALERT_True                 2.741142e-01 -8.867233e-02 -0.271504
# ANGER_False               -9.795701e-17  2.855439e-16 -0.001190
# ANGER_True                 5.527264e-17 -2.596234e-16  0.001190
# ...

# %%
df1.columns
# Out:
# Index(['bpm', 'calories', 'distance', 'filteredDemographicVO2Max',
#        'lightly_active_minutes', 'moderately_active_minutes',
#        'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps',
#        'ALERT_False', 'ALERT_True', 'ANGER_False', 'ANGER_True', 'FEAR_False',
#        'FEAR_True', 'HAPPY_False', 'HAPPY_True', 'NEUTRAL_False',
#        'NEUTRAL_True', 'RESTED/RELAXED_False', 'RESTED/RELAXED_True',
#        'SAD_False', 'SAD_True', 'SURPRISE_False', 'SURPRISE_True',
#        'TENSE/ANXIOUS_False', 'TENSE/ANXIOUS_True', 'TIRED_False',
#        'TIRED_True', 'ENTERTAINMENT_False', 'ENTERTAINMENT_True', 'GYM_False',
#        'GYM_True', 'HOME_False', 'HOME_True', 'HOME_OFFICE_False',
#        'OTHER_False', 'OTHER_True', 'OUTDOORS_False', 'OUTDOORS_True',
#        'TRANSIT_False', 'TRANSIT_True', 'WORK/SCHOOL_False',
#        'WORK/SCHOOL_True'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import ticker

# Define the columns for the x-axis and y-axis
y_columns = ['bpm', 'calories', 'distance', 'filteredDemographicVO2Max',
             'lightly_active_minutes', 'moderately_active_minutes',
             'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps']
x_columns = ['ALERT_True', 'HAPPY_True', 'NEUTRAL_True', 'RESTED/RELAXED_True',
             'SAD_True', 'TENSE/ANXIOUS_True', 'TIRED_True', 'ENTERTAINMENT_True']

# Subset the correlation matrix
cor = cor.loc[y_columns, x_columns]

# Simplify x-axis labels
simplified_labels = [label.split('_')[0].title() for label in x_columns]

plt.figure(figsize=(12, 8))

# Create the heatmap and bold the annotated values
heatmap = sns.heatmap(
    data=cor, 
    annot=True, 
    vmin=-0.4, 
    vmax=0.6, 
    annot_kws={"weight": "bold"},  # Bold annotations
    cbar_kws={'format': '%.2f'}  # Format color bar values
)

# Set x-axis labels
heatmap.set_xticklabels(simplified_labels, rotation=30, fontsize=14, fontweight='bold')
heatmap.set_yticklabels(y_columns, fontsize=14, fontweight='bold')

# Get the color bar and bold its tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.yaxis.set_major_formatter(ticker.ScalarFormatter())
colorbar.ax.yaxis.set_tick_params(labelsize=12)
for tick in colorbar.ax.get_yticklabels():
    tick.set_fontweight('bold')  # Set font weight to bold for color bar ticks

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the columns for the x-axis and y-axis
y_columns = ['bpm', 'calories', 'distance', 'filteredDemographicVO2Max',
             'lightly_active_minutes', 'moderately_active_minutes',
             'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps']
x_columns = ['ALERT_True', 'HAPPY_True', 'NEUTRAL_True', 'RESTED/RELAXED_True',
             'SAD_True', 'TENSE/ANXIOUS_True', 'TIRED_True', 'ENTERTAINMENT_True']

# Subset the correlation matrix
cor = cor.loc[y_columns, x_columns]

# Simplify x-axis labels
simplified_labels = [label.split('_')[0].title() for label in x_columns]

plt.figure(figsize=(12, 8))
# heatmap = sns.heatmap(data=cor, annot=True)
#heatmap = sns.heatmap(data=cor, annot=True, vmin=-0.4, vmax=0.6)

# Set x-axis labels
heatmap = sns.heatmap(
    data=cor, 
    annot=True, 
    vmin=-0.4, 
    vmax=0.6, 
    annot_kws={"weight": "bold"}  # Make annotations bold
)


#---------------------------------------------------------------------------
heatmap.set_xticklabels(simplified_labels, rotation=30, fontsize=14,fontweight='bold')
heatmap.set_yticklabels(y_columns, fontsize=14,fontweight='bold')
#--------------------------------------------------------------------

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the columns for the x-axis and y-axis
y_columns = ['bpm', 'calories', 'distance', 'filteredDemographicVO2Max',
             'lightly_active_minutes', 'moderately_active_minutes',
             'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps']
x_columns = ['ALERT_True', 'HAPPY_True', 'NEUTRAL_True', 'RESTED/RELAXED_True',
             'SAD_True', 'TENSE/ANXIOUS_True', 'TIRED_True', 'ENTERTAINMENT_True']

# Subset the correlation matrix
cor = cor.loc[y_columns, x_columns]

# Simplify x-axis labels
simplified_labels = [label.split('_')[0].title() for label in x_columns]

plt.figure(figsize=(12, 8))

# Create the heatmap and bold the annotated values
heatmap = sns.heatmap(
    data=cor, 
    annot=True, 
    vmin=-0.4, 
    vmax=0.6, 
    annot_kws={"weight": "bold"},  # Bold annotations
    cbar_kws={'weight': '%.2f'}  # Format color bar values
)

# Set x-axis labels
heatmap.set_xticklabels(simplified_labels, rotation=30, fontsize=14, fontweight='bold')
heatmap.set_yticklabels(y_columns, fontsize=14, fontweight='bold')

# Get the color bar and set its tick labels to bold
colorbar = heatmap.collections[0].colorbar
colorbar.ax.yaxis.set_tick_params(labelsize=12, width=2)
colorbar.ax.yaxis.set_tick_params(labelsize=14, labelweight='bold')

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[688], line 20
#      17 plt.figure(figsize=(12, 8))
#      19 # Create the heatmap and bold the annotated values
# ---> 20 heatmap = sns.heatmap(
#      21     data=cor,
#      22     annot=True,
#      23     vmin=-0.4,
#      24     vmax=0.6,
#      25     annot_kws={"weight": "bold"},  # Bold annotations
#      26     cbar_kws={'weight': '%.2f'}  # Format color bar values
#      27 )
#      29 # Set x-axis labels
#      30 heatmap.set_xticklabels(simplified_labels, rotation=30, fontsize=14, fontweight='bold')
#
# File c:\Python310\lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the columns for the x-axis and y-axis
y_columns = ['bpm', 'calories', 'distance', 'filteredDemographicVO2Max',
             'lightly_active_minutes', 'moderately_active_minutes',
             'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps']
x_columns = ['ALERT_True', 'HAPPY_True', 'NEUTRAL_True', 'RESTED/RELAXED_True',
             'SAD_True', 'TENSE/ANXIOUS_True', 'TIRED_True', 'ENTERTAINMENT_True']

# Subset the correlation matrix
cor = cor.loc[y_columns, x_columns]

# Simplify x-axis labels
simplified_labels = [label.split('_')[0].title() for label in x_columns]

plt.figure(figsize=(12, 8))
sns.heatmap(data=cor, annot=True)

# Set x-axis labels
plt.xticks(rotation=70)

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import pandas as pd
# replace with the actual path to your CSV file
file_path = 'data/Integrated_with_Sema.pkl'
df = pd.read_pickle(file_path)
specific_user_ids = ['621e2f3967b776a240c654db', '621e2f7a67b776a240f14425', '621e2f9167b776a240011ccb', '621e2fb367b776a24015accd', '621e2fce67b776a240279baa', '621e30c867b776a240d4aa6c', '621e30f467b776a240f22944',
                     '621e323667b776a240f19134', '621e324e67b776a2400191cb', '621e329067b776a2402ffad2', '621e32af67b776a24045b4cf', '621e331067b776a24085dd3f', '621e337667b776a240ce78ab', '621e33b067b776a240f39e56',
                     '621e366567b776a24076a727'
                     ]
filtered_df = df[df['id'].isin(specific_user_ids)]
filtered_df.to_csv('data/filtered_users_above60.csv', index=False)
filtered_df
# Out:
#                             id       date  nightly_temperature  nremhr  \
# 746   621e2f3967b776a240c654db 2021-05-24                  NaN  69.820
# 747   621e2f3967b776a240c654db 2021-05-25            33.389948  59.727
# 748   621e2f3967b776a240c654db 2021-05-26            32.761934  60.670
# 749   621e2f3967b776a240c654db 2021-05-27            33.252421  58.036
# 750   621e2f3967b776a240c654db 2021-05-28            31.903324  59.781
# ...                        ...        ...                  ...     ...
# 6554  621e366567b776a24076a727 2022-01-18                  NaN     NaN
# 6555  621e366567b776a24076a727 2022-01-19                  NaN     NaN
# 6556  621e366567b776a24076a727 2022-01-20                  NaN     NaN
# 6557  621e366567b776a24076a727 2022-01-21                  NaN     NaN
# 6558  621e366567b776a24076a727 2022-01-22                  NaN     NaN
#
#        rmssd  entropy  spo2  full_sleep_breathing_rate  \
# 746   28.594    2.621   NaN                       16.4
# ...

# %%
filtered_df.columns
# Out:
# Index(['id', 'date', 'nightly_temperature', 'nremhr', 'rmssd', 'entropy',
#        'spo2', 'full_sleep_breathing_rate', 'full_sleep_standard_deviation',
#        'full_sleep_signal_to_noise', 'deep_sleep_breathing_rate',
#        'deep_sleep_standard_deviation', 'deep_sleep_signal_to_noise',
#        'light_sleep_breathing_rate', 'light_sleep_standard_deviation',
#        'light_sleep_signal_to_noise', 'rem_sleep_breathing_rate',
#        'rem_sleep_standard_deviation', 'rem_sleep_signal_to_noise',
#        'stress_score', 'sleep_points_percentage', 'exertion_points_percentage',
#        'responsiveness_points_percentage', 'daily_temperature_variation',
#        'badgeType', 'calories', 'filteredDemographicVO2Max', 'distance',
#        'activityType', 'bpm', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'mindfulness_session', 'scl_avg', 'resting_hr', 'sleep_duration',
# ...

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('data/filtered_users_above60.csv')

# Combine emotion columns into a single "Emotions" column
emotion_columns = ['ALERT', 'ANGER', 'FEAR', 'HAPPY', 'NEUTRAL',
                   'RESTED/RELAXED', 'SAD', 'SURPRISE', 'TENSE/ANXIOUS', 'TIRED']
df['Emotions'] = df[emotion_columns].idxmax(axis=1)
df.drop(emotion_columns, axis=1, inplace=True)
df.to_csv('ML_algorithm/data/path_to_save_updated_csv_file_15_users.csv', index=False)
df.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17036\1118205297.py:9: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df['Emotions'] = df[emotion_columns].idxmax(axis=1)
#                          id        date  nightly_temperature  nremhr   rmssd  \
# 0  621e2f3967b776a240c654db  2021-05-24                  NaN  69.820  28.594
# 1  621e2f3967b776a240c654db  2021-05-25            33.389948  59.727  38.892
# 2  621e2f3967b776a240c654db  2021-05-26            32.761934  60.670  43.005
# 3  621e2f3967b776a240c654db  2021-05-27            33.252421  58.036  44.964
# 4  621e2f3967b776a240c654db  2021-05-28            31.903324  59.781  39.292
#
#    entropy  spo2  full_sleep_breathing_rate  full_sleep_standard_deviation  \
# 0    2.621   NaN                       16.4                            0.7
# 1    2.913   NaN                       15.6                            0.8
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1278 entries, 746 to 6558
# Data columns (total 78 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1278 non-null   object
#  1   date                              1278 non-null   datetime64[ns]
#  2   nightly_temperature               922 non-null    float64
#  3   nremhr                            618 non-null    float64
#  4   rmssd                             618 non-null    float64
#  5   entropy                           618 non-null    float64
#  6   spo2                              441 non-null    float64
#  7   full_sleep_breathing_rate         623 non-null    float64
#  8   full_sleep_standard_deviation     623 non-null    float64
#  9   full_sleep_signal_to_noise        623 non-null    float64
#  10  deep_sleep_breathing_rate         623 non-null    float64
# ...

# %%
columns_to_check = ['ALERT', 'HAPPY', 'NEUTRAL',
                    'RESTED/RELAXED', 'SAD', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME', 'HOME_OFFICE', 'OTHER', 'OUTDOORS',
                    'TRANSIT', 'WORK/SCHOOL']
filtered_df = filtered_df[filtered_df[columns_to_check].any(axis=1)].copy()

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 935 entries, 746 to 6552
# Data columns (total 78 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                935 non-null    object
#  1   date                              935 non-null    datetime64[ns]
#  2   nightly_temperature               829 non-null    float64
#  3   nremhr                            548 non-null    float64
#  4   rmssd                             548 non-null    float64
#  5   entropy                           548 non-null    float64
#  6   spo2                              385 non-null    float64
#  7   full_sleep_breathing_rate         550 non-null    float64
#  8   full_sleep_standard_deviation     550 non-null    float64
#  9   full_sleep_signal_to_noise        550 non-null    float64
#  10  deep_sleep_breathing_rate         550 non-null    float64
# ...

# %%
filtered_df = filtered_df.drop(
    ['light_sleep_breathing_rate', 'light_sleep_standard_deviation', 'light_sleep_signal_to_noise', 'scl_avg'], axis=1)
filtered_df
# Out:
#                             id       date  nightly_temperature  nremhr  \
# 746   621e2f3967b776a240c654db 2021-05-24                  NaN  69.820
# 747   621e2f3967b776a240c654db 2021-05-25            33.389948  59.727
# 748   621e2f3967b776a240c654db 2021-05-26            32.761934  60.670
# 749   621e2f3967b776a240c654db 2021-05-27            33.252421  58.036
# 750   621e2f3967b776a240c654db 2021-05-28            31.903324  59.781
# ...                        ...        ...                  ...     ...
# 6548  621e366567b776a24076a727 2022-01-12            33.074988  48.064
# 6549  621e366567b776a24076a727 2022-01-13            33.211472  48.371
# 6550  621e366567b776a24076a727 2022-01-14            33.143311  45.392
# 6551  621e366567b776a24076a727 2022-01-15            33.788481  51.656
# 6552  621e366567b776a24076a727 2022-01-16            33.277004  46.697
#
#        rmssd  entropy  spo2  full_sleep_breathing_rate  \
# 746   28.594    2.621   NaN                       16.4
# ...

# %%
filtered_df = filtered_df.drop(
    ['<no-response>'], axis=1)
filtered_df
# Out:
#                             id       date  nightly_temperature  nremhr  \
# 746   621e2f3967b776a240c654db 2021-05-24                  NaN  69.820
# 747   621e2f3967b776a240c654db 2021-05-25            33.389948  59.727
# 748   621e2f3967b776a240c654db 2021-05-26            32.761934  60.670
# 749   621e2f3967b776a240c654db 2021-05-27            33.252421  58.036
# 750   621e2f3967b776a240c654db 2021-05-28            31.903324  59.781
# ...                        ...        ...                  ...     ...
# 6548  621e366567b776a24076a727 2022-01-12            33.074988  48.064
# 6549  621e366567b776a24076a727 2022-01-13            33.211472  48.371
# 6550  621e366567b776a24076a727 2022-01-14            33.143311  45.392
# 6551  621e366567b776a24076a727 2022-01-15            33.788481  51.656
# 6552  621e366567b776a24076a727 2022-01-16            33.277004  46.697
#
#        rmssd  entropy  spo2  full_sleep_breathing_rate  \
# 746   28.594    2.621   NaN                       16.4
# ...

# %%
check = filtered_df[['id', 'date', 'bpm', 'calories', 'distance', 'filteredDemographicVO2Max', 'lightly_active_minutes', 'moderately_active_minutes',
                     'very_active_minutes', 'sedentary_minutes', 'mindfulness_session',
                     'resting_hr', 'steps', 'minutes_in_default_zone_1',
                     'minutes_below_default_zone_1', 'minutes_in_default_zone_2',
                     'minutes_in_default_zone_3', 'age', 'gender', 'bmi', 'step_goal',
                     'min_goal', 'max_goal', 'step_goal_label', 'ALERT', 'ANGER', 'FEAR',
                     'HAPPY', 'NEUTRAL', 'RESTED/RELAXED', 'SAD', 'SURPRISE',
                     'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME', 'HOME_OFFICE',
                     'OTHER', 'OUTDOORS', 'TRANSIT', 'WORK/SCHOOL']].copy()
check
# Out:
#                             id       date        bpm  calories  distance  \
# 746   621e2f3967b776a240c654db 2021-05-24  72.790064   1690.71     958.5
# 747   621e2f3967b776a240c654db 2021-05-25  75.598137   1957.94    4154.7
# 748   621e2f3967b776a240c654db 2021-05-26  77.432668   2039.20    4187.6
# 749   621e2f3967b776a240c654db 2021-05-27  82.111651   2074.80    3819.1
# 750   621e2f3967b776a240c654db 2021-05-28  83.294481   2504.10    7107.8
# ...                        ...        ...        ...       ...       ...
# 6548  621e366567b776a24076a727 2022-01-12  67.932913   3785.79   12506.6
# 6549  621e366567b776a24076a727 2022-01-13  65.320744   3180.12    7933.9
# 6550  621e366567b776a24076a727 2022-01-14  68.204038   3848.64   13166.0
# 6551  621e366567b776a24076a727 2022-01-15  68.082687   3892.06   14403.7
# 6552  621e366567b776a24076a727 2022-01-16  65.622004   3800.45   14638.6
#
#       filteredDemographicVO2Max lightly_active_minutes  \
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['bpm']] = imputer.fit_transform(check[['bpm']])

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['calories',
       'distance']] = imputer.fit_transform(check[['calories', 'distance']])

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['very_active_minutes', 'sedentary_minutes']] = imputer.fit_transform(
    check[['very_active_minutes', 'sedentary_minutes']])

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 935 entries, 746 to 6552
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            935 non-null    object
#  1   date                          935 non-null    datetime64[ns]
#  2   bpm                           935 non-null    float64
#  3   calories                      935 non-null    float64
#  4   distance                      935 non-null    float64
#  5   filteredDemographicVO2Max     894 non-null    float64
#  6   lightly_active_minutes        934 non-null    object
#  7   moderately_active_minutes     934 non-null    object
#  8   very_active_minutes           935 non-null    float64
#  9   sedentary_minutes             935 non-null    float64
#  10  mindfulness_session           935 non-null    object
#  11  resting_hr                    895 non-null    float64
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['filteredDemographicVO2Max']] = imputer.fit_transform(
    check[['filteredDemographicVO2Max']])

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
check[['lightly_active_minutes',
       'moderately_active_minutes', 'resting_hr', 'steps',
       'minutes_in_default_zone_1', 'minutes_below_default_zone_1',
       'minutes_in_default_zone_2', 'minutes_in_default_zone_3']] = imputer.fit_transform(
    check[['lightly_active_minutes',
           'moderately_active_minutes', 'resting_hr', 'steps',
           'minutes_in_default_zone_1', 'minutes_below_default_zone_1',
           'minutes_in_default_zone_2', 'minutes_in_default_zone_3']])

# %%
check1 = check[['id', 'date', 'bpm', 'calories', 'distance',
                'filteredDemographicVO2Max', 'lightly_active_minutes',
               'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps', 'ALERT', 'ANGER', 'FEAR', 'HAPPY', 'NEUTRAL', 'RESTED/RELAXED', 'SAD',
                'SURPRISE', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME',
                'HOME_OFFICE', 'OTHER', 'OUTDOORS', 'TRANSIT', 'WORK/SCHOOL']].copy()

# %%
check1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 935 entries, 746 to 6552
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         935 non-null    object
#  1   date                       935 non-null    datetime64[ns]
#  2   bpm                        935 non-null    float64
#  3   calories                   935 non-null    float64
#  4   distance                   935 non-null    float64
#  5   filteredDemographicVO2Max  935 non-null    float64
#  6   lightly_active_minutes     935 non-null    float64
#  7   moderately_active_minutes  935 non-null    float64
#  8   very_active_minutes        935 non-null    float64
#  9   sedentary_minutes          935 non-null    float64
#  10  resting_hr                 935 non-null    float64
#  11  steps                      935 non-null    float64
#  12  ALERT                      935 non-null    object
# ...

# %%
columns_to_encode = ['ALERT', 'ANGER', 'FEAR', 'HAPPY', 'NEUTRAL',
                     'RESTED/RELAXED', 'SAD', 'SURPRISE', 'TENSE/ANXIOUS', 'TIRED', 'ENTERTAINMENT', 'GYM', 'HOME', 'HOME_OFFICE', 'OTHER', 'OUTDOORS',
                     'TRANSIT', 'WORK/SCHOOL']

# Ensure these columns exist in the DataFrame
columns_to_encode = [
    col for col in columns_to_encode if col in check1.columns]

# Apply one-hot encoding to the specified columns
X_input_encoded = pd.get_dummies(check1, columns=columns_to_encode)

# Print the original and encoded dataframes
print("Original DataFrame:")
print(check1.head())

print("\nDataFrame after One-Hot Encoding:")
print(X_input_encoded.head())
# Out:
# Original DataFrame:
#                            id       date        bpm  calories  distance  \
# 746  621e2f3967b776a240c654db 2021-05-24  72.790064   1690.71     958.5
# 747  621e2f3967b776a240c654db 2021-05-25  75.598137   1957.94    4154.7
# 748  621e2f3967b776a240c654db 2021-05-26  77.432668   2039.20    4187.6
# 749  621e2f3967b776a240c654db 2021-05-27  82.111651   2074.80    3819.1
# 750  621e2f3967b776a240c654db 2021-05-28  83.294481   2504.10    7107.8
#
#      filteredDemographicVO2Max  lightly_active_minutes  \
# 746                  49.380030                    60.0
# 747                  49.885883                    65.0
# 748                  49.381510                    54.0
# 749                  49.437690                    69.0
# 750                  49.530250                   101.0
#
#      moderately_active_minutes  very_active_minutes  sedentary_minutes  ...  \
# 746                        0.0                  0.0              880.0  ...
# ...

# %%
check1
# Out:
#                             id       date        bpm  calories  distance  \
# 746   621e2f3967b776a240c654db 2021-05-24  72.790064   1690.71     958.5
# 747   621e2f3967b776a240c654db 2021-05-25  75.598137   1957.94    4154.7
# 748   621e2f3967b776a240c654db 2021-05-26  77.432668   2039.20    4187.6
# 749   621e2f3967b776a240c654db 2021-05-27  82.111651   2074.80    3819.1
# 750   621e2f3967b776a240c654db 2021-05-28  83.294481   2504.10    7107.8
# ...                        ...        ...        ...       ...       ...
# 6548  621e366567b776a24076a727 2022-01-12  67.932913   3785.79   12506.6
# 6549  621e366567b776a24076a727 2022-01-13  65.320744   3180.12    7933.9
# 6550  621e366567b776a24076a727 2022-01-14  68.204038   3848.64   13166.0
# 6551  621e366567b776a24076a727 2022-01-15  68.082687   3892.06   14403.7
# 6552  621e366567b776a24076a727 2022-01-16  65.622004   3800.45   14638.6
#
#       filteredDemographicVO2Max  lightly_active_minutes  \
# ...

# %%
X_input_encoded.head()
# Out:
#                            id       date        bpm  calories  distance  \
# 746  621e2f3967b776a240c654db 2021-05-24  72.790064   1690.71     958.5
# 747  621e2f3967b776a240c654db 2021-05-25  75.598137   1957.94    4154.7
# 748  621e2f3967b776a240c654db 2021-05-26  77.432668   2039.20    4187.6
# 749  621e2f3967b776a240c654db 2021-05-27  82.111651   2074.80    3819.1
# 750  621e2f3967b776a240c654db 2021-05-28  83.294481   2504.10    7107.8
#
#      filteredDemographicVO2Max  lightly_active_minutes  \
# 746                  49.380030                    60.0
# 747                  49.885883                    65.0
# 748                  49.381510                    54.0
# 749                  49.437690                    69.0
# 750                  49.530250                   101.0
#
#      moderately_active_minutes  very_active_minutes  sedentary_minutes  ...  \
# 746                        0.0                  0.0              880.0  ...
# ...

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
numeric_cols = X_input_encoded.select_dtypes(
    include=np.number).columns.tolist()


numeric_cols
# Out:
# ['bpm',
#  'calories',
#  'distance',
#  'filteredDemographicVO2Max',
#  'lightly_active_minutes',
#  'moderately_active_minutes',
#  'very_active_minutes',
#  'sedentary_minutes',
#  'resting_hr',
#  'steps']

# %%
categorical_cols = X_input_encoded.select_dtypes('bool').columns.tolist()
categorical_cols
# Out:
# ['ALERT_False',
#  'ALERT_True',
#  'ANGER_False',
#  'FEAR_False',
#  'HAPPY_False',
#  'HAPPY_True',
#  'NEUTRAL_False',
#  'NEUTRAL_True',
#  'RESTED/RELAXED_False',
#  'RESTED/RELAXED_True',
#  'SAD_False',
#  'SAD_True',
#  'SURPRISE_False',
#  'TENSE/ANXIOUS_False',
#  'TENSE/ANXIOUS_True',
#  'TIRED_False',
#  'TIRED_True',
#  'ENTERTAINMENT_False',
#  'ENTERTAINMENT_True',
#  'GYM_False',
#  'GYM_True',
#  'HOME_False',
#  'HOME_True',
#  'HOME_OFFICE_False',
#  'HOME_OFFICE_True',
#  'OTHER_False',
#  'OTHER_True',
#  'OUTDOORS_False',
#  'OUTDOORS_True',
#  'TRANSIT_False',
#  'TRANSIT_True',
#  'WORK/SCHOOL_False',
#  'WORK/SCHOOL_True']

# %%
X_input_encoded[numeric_cols].describe()
# Out:
#               bpm     calories      distance  filteredDemographicVO2Max  \
# count  935.000000   935.000000    935.000000                 935.000000
# mean    78.248439  2554.385075   6012.598435                  49.885883
# std      8.746556   669.839132   3526.060480                   5.372126
# min     48.387486  1120.510000     13.100000                  39.120340
# 25%     73.086725  2028.695000   3522.100000                  44.818925
# 50%     78.164844  2465.350000   5456.000000                  49.952780
# 75%     83.305555  3011.285000   8052.450000                  54.244465
# max    117.959382  6184.320000  22562.700000                  61.309840
#
#        lightly_active_minutes  moderately_active_minutes  very_active_minutes  \
# count              935.000000                 935.000000           935.000000
# mean               217.296257                  25.425668            22.007495
# std                101.909515                  30.748071            33.141591
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_input_encoded[numeric_cols])
# Out:
# MinMaxScaler()

# %%
print('Minimum:')
list(scaler.data_min_)
# Out:
# Minimum:
# [48.387485970819306,
#  1120.51,
#  13.1,
#  39.120340000000006,
#  0.0,
#  0.0,
#  0.0,
#  264.0,
#  48.2032356262207,
#  18.0]

# %%
print('Maximum:')
list(scaler.data_max_)
# Out:
# Maximum:
# [117.95938215102974,
#  6184.32,
#  22562.7,
#  61.30984000000001,
#  585.0,
#  289.0,
#  369.0,
#  1440.0,
#  83.64772891998291,
#  31513.0]

# %%
X_input_encoded[numeric_cols] = scaler.transform(X_input_encoded[numeric_cols])

# %%
X_input_encoded.describe()
# Out:
#                                 date         bpm    calories    distance  \
# count                            935  935.000000  935.000000  935.000000
# mean   2021-09-02 12:45:25.989304832    0.429210    0.283161    0.266058
# min              2021-05-24 00:00:00    0.000000    0.000000    0.000000
# 25%              2021-06-19 00:00:00    0.355017    0.179348    0.155613
# 50%              2021-07-16 00:00:00    0.428008    0.265579    0.241375
# 75%              2021-12-08 12:00:00    0.501899    0.373390    0.356519
# max              2022-01-17 00:00:00    1.000000    1.000000    1.000000
# std                              NaN    0.125720    0.132280    0.156369
#
#        filteredDemographicVO2Max  lightly_active_minutes  \
# count                 935.000000              935.000000
# mean                    0.485164                0.371447
# min                     0.000000                0.000000
# 25%                     0.256814                0.255556
# ...

# %%
X_input_encoded
# Out:
#                             id       date       bpm  calories  distance  \
# 746   621e2f3967b776a240c654db 2021-05-24  0.350753  0.112603  0.041925
# 747   621e2f3967b776a240c654db 2021-05-25  0.391116  0.165375  0.183666
# 748   621e2f3967b776a240c654db 2021-05-26  0.417484  0.181423  0.185125
# 749   621e2f3967b776a240c654db 2021-05-27  0.484738  0.188453  0.168783
# 750   621e2f3967b776a240c654db 2021-05-28  0.501740  0.273231  0.314626
# ...                        ...        ...       ...       ...       ...
# 6548  621e366567b776a24076a727 2022-01-12  0.280939  0.526339  0.554045
# 6549  621e366567b776a24076a727 2022-01-13  0.243392  0.406731  0.351261
# 6550  621e366567b776a24076a727 2022-01-14  0.284836  0.538750  0.583288
# 6551  621e366567b776a24076a727 2022-01-15  0.283091  0.547325  0.638175
# 6552  621e366567b776a24076a727 2022-01-16  0.247722  0.529234  0.648592
#
#       filteredDemographicVO2Max  lightly_active_minutes  \
# ...

# %%
X_input_encoded.to_csv(
    'ML_algorithm/data/fifiteen_users_data.csv', index=False)

# %%
X_input_encoded.columns
# Out:
# Index(['id', 'date', 'bpm', 'calories', 'distance',
#        'filteredDemographicVO2Max', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'resting_hr', 'steps', 'ALERT_False', 'ALERT_True', 'ANGER_False',
#        'FEAR_False', 'HAPPY_False', 'HAPPY_True', 'NEUTRAL_False',
#        'NEUTRAL_True', 'RESTED/RELAXED_False', 'RESTED/RELAXED_True',
#        'SAD_False', 'SAD_True', 'SURPRISE_False', 'TENSE/ANXIOUS_False',
#        'TENSE/ANXIOUS_True', 'TIRED_False', 'TIRED_True',
#        'ENTERTAINMENT_False', 'ENTERTAINMENT_True', 'GYM_False', 'GYM_True',
#        'HOME_False', 'HOME_True', 'HOME_OFFICE_False', 'HOME_OFFICE_True',
#        'OTHER_False', 'OTHER_True', 'OUTDOORS_False', 'OUTDOORS_True',
#        'TRANSIT_False', 'TRANSIT_True', 'WORK/SCHOOL_False',
#        'WORK/SCHOOL_True'],
#       dtype='object')

# %%
df1 = X_input_encoded[['bpm', 'calories', 'distance',
                       'filteredDemographicVO2Max', 'lightly_active_minutes',
                       'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
                       'resting_hr', 'steps', 'ALERT_False', 'ALERT_True', 'ANGER_False',
                       'FEAR_False', 'HAPPY_False', 'HAPPY_True', 'NEUTRAL_False',
                       'NEUTRAL_True', 'RESTED/RELAXED_False', 'RESTED/RELAXED_True',
                       'SAD_False', 'SAD_True', 'SURPRISE_False', 'TENSE/ANXIOUS_False',
                       'TENSE/ANXIOUS_True', 'TIRED_False', 'TIRED_True',
                       'ENTERTAINMENT_False', 'ENTERTAINMENT_True', 'GYM_False', 'GYM_True',
                       'HOME_False', 'HOME_True', 'HOME_OFFICE_False', 'HOME_OFFICE_True',
                       'OTHER_False', 'OTHER_True', 'OUTDOORS_False', 'OUTDOORS_True',
                       'TRANSIT_False', 'TRANSIT_True', 'WORK/SCHOOL_False',
                       'WORK/SCHOOL_True']].copy()
df1
# Out:
#            bpm  calories  distance  filteredDemographicVO2Max  \
# 746   0.350753  0.112603  0.041925                   0.462367
# 747   0.391116  0.165375  0.183666                   0.485164
# 748   0.417484  0.181423  0.185125                   0.462434
# 749   0.484738  0.188453  0.168783                   0.464965
# 750   0.501740  0.273231  0.314626                   0.469137
# ...        ...       ...       ...                        ...
# 6548  0.280939  0.526339  0.554045                   0.458862
# 6549  0.243392  0.406731  0.351261                   0.461423
# 6550  0.284836  0.538750  0.583288                   0.465898
# 6551  0.283091  0.547325  0.638175                   0.469199
# 6552  0.247722  0.529234  0.648592                   0.485164
#
#       lightly_active_minutes  moderately_active_minutes  very_active_minutes  \
# 746                 0.102564                   0.000000             0.000000
# ...

# %%
cor = df1.corr()
cor
# Out:
#                                 bpm  calories  distance  \
# bpm                        1.000000  0.237429  0.125324
# calories                   0.237429  1.000000  0.779817
# distance                   0.125324  0.779817  1.000000
# filteredDemographicVO2Max -0.414974  0.110593  0.049927
# lightly_active_minutes     0.103470  0.565676  0.635900
# moderately_active_minutes  0.279533  0.722734  0.645158
# very_active_minutes        0.311651  0.682225  0.608572
# sedentary_minutes          0.011275 -0.488924 -0.470595
# resting_hr                 0.710014 -0.090057 -0.137825
# steps                      0.156014  0.803985  0.963900
# ALERT_False                0.000260 -0.027659  0.060017
# ALERT_True                -0.000260  0.027659 -0.060017
# ANGER_False                     NaN       NaN       NaN
# FEAR_False                      NaN       NaN       NaN
# HAPPY_False               -0.001100 -0.014523 -0.061670
# HAPPY_True                 0.001100  0.014523  0.061670
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the columns for the x-axis and y-axis
y_columns = ['bpm', 'calories', 'distance', 'filteredDemographicVO2Max',
             'lightly_active_minutes', 'moderately_active_minutes',
             'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps']
x_columns = ['ALERT_True', 'HAPPY_True', 'NEUTRAL_True', 'RESTED/RELAXED_True',
             'SAD_True', 'TENSE/ANXIOUS_True', 'TIRED_True', 'ENTERTAINMENT_True']

# Subset the correlation matrix
cor = cor.loc[y_columns, x_columns]

# Simplify x-axis labels
simplified_labels = [label.split('_')[0].title() for label in x_columns]

plt.figure(figsize=(12, 8))
sns.heatmap(data=cor, annot=True, vmin=-0.4, vmax=0.6)

# Set x-axis labels
plt.xticks(rotation=70)

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the columns for the x-axis and y-axis
y_columns = ['bpm', 'calories', 'distance', 'filteredDemographicVO2Max',
             'lightly_active_minutes', 'moderately_active_minutes',
             'very_active_minutes', 'sedentary_minutes', 'resting_hr', 'steps']
x_columns = ['ALERT_True', 'HAPPY_True', 'NEUTRAL_True', 'RESTED/RELAXED_True',
             'SAD_True', 'TENSE/ANXIOUS_True', 'TIRED_True', 'ENTERTAINMENT_True']

# Subset the correlation matrix
cor = cor.loc[y_columns, x_columns]

# Simplify x-axis labels
simplified_labels = [label.split('_')[0].title() for label in x_columns]

plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(data=cor, annot=True, vmin=-0.4, vmax=0.6)

# Set x-axis labels
heatmap.set_xticklabels(simplified_labels, rotation=-70)

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('ML_algorithm/data/fifiteen_users_data.csv')
df.columns
# Out:
# Index(['id', 'date', 'bpm', 'calories', 'distance',
#        'filteredDemographicVO2Max', 'lightly_active_minutes',
#        'moderately_active_minutes', 'very_active_minutes', 'sedentary_minutes',
#        'resting_hr', 'steps', 'ALERT_False', 'ALERT_True', 'ANGER_False',
#        'FEAR_False', 'HAPPY_False', 'HAPPY_True', 'NEUTRAL_False',
#        'NEUTRAL_True', 'RESTED/RELAXED_False', 'RESTED/RELAXED_True',
#        'SAD_False', 'SAD_True', 'SURPRISE_False', 'TENSE/ANXIOUS_False',
#        'TENSE/ANXIOUS_True', 'TIRED_False', 'TIRED_True',
#        'ENTERTAINMENT_False', 'ENTERTAINMENT_True', 'GYM_False', 'GYM_True',
#        'HOME_False', 'HOME_True', 'HOME_OFFICE_False', 'HOME_OFFICE_True',
#        'OTHER_False', 'OTHER_True', 'OUTDOORS_False', 'OUTDOORS_True',
#        'TRANSIT_False', 'TRANSIT_True', 'WORK/SCHOOL_False',
#        'WORK/SCHOOL_True'],
#       dtype='object')

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('ML_algorithm/data/fifiteen_users_data.csv')

# Combine emotion columns into a single "Emotions" column
emotion_columns = ['ALERT_True', 'HAPPY_True', 'NEUTRAL_True',
                   'RESTED/RELAXED_True', 'SAD_True', 'TENSE/ANXIOUS_True', 'TIRED_True']
df['Emotions'] = df[emotion_columns].idxmax(
    axis=1).apply(lambda x: x.replace('_True', ''))

# Drop the original emotion columns
df.drop(emotion_columns, axis=1, inplace=True)

# Optional: Drop the 'False' columns as well if they are no longer needed
false_columns = [col for col in df.columns if col.endswith('_False')]
df.drop(false_columns, axis=1, inplace=True)

# Save the DataFrame with the new "Emotions" column
df.to_csv('ML_algorithm/data/fifiteen_users_data_updated_csv_file.csv', index=False)

# Display the first few rows to verify the changes
df.head()
# Out:
#                          id        date       bpm  calories  distance  \
# 0  621e2f3967b776a240c654db  2021-05-24  0.350753  0.112603  0.041925
# 1  621e2f3967b776a240c654db  2021-05-25  0.391116  0.165375  0.183666
# 2  621e2f3967b776a240c654db  2021-05-26  0.417484  0.181423  0.185125
# 3  621e2f3967b776a240c654db  2021-05-27  0.484738  0.188453  0.168783
# 4  621e2f3967b776a240c654db  2021-05-28  0.501740  0.273231  0.314626
#
#    filteredDemographicVO2Max  lightly_active_minutes  \
# 0                   0.462367                0.102564
# 1                   0.485164                0.111111
# 2                   0.462434                0.092308
# 3                   0.464965                0.117949
# 4                   0.469137                0.172650
#
#    moderately_active_minutes  very_active_minutes  sedentary_minutes  ...  \
# 0                   0.000000             0.000000           0.523810  ...
# ...
